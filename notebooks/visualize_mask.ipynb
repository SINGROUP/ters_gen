# %%
from src.datasets import Ters_dataset_filtered_skip
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.datasets import Ters_dataset_filtered_skip
#
# ModuleNotFoundError: No module named 'src'

# %%
#dataset = Ters_dataset_filtered_skip('/scratch/phys/sin/sethih1/data_files/all_group_images_new', [0, 4000])
dataset = Ters_dataset_filtered_skip('/scratch/phys/sin/sethih1/data_files/balanced_group', [0, 4000])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #dataset = Ters_dataset_filtered_skip('/scratch/phys/sin/sethih1/data_files/all_group_images_new', [0, 4000])
# ----> 2 dataset = Ters_dataset_filtered_skip('/scratch/phys/sin/sethih1/data_files/balanced_group', [0, 4000])
#
# TypeError: Ters_dataset_filtered_skip.__init__() missing 1 required positional argument: 'num_channels'

# %%
sample = dataset[0]
mol_images_tensor, freq_tensor, target_image, bonds = sample

# %%
dataset.target_images.shape

# %%
import numpy as np
import matplotlib.pyplot as plt

npz_file = '/scratch/phys/sin/sethih1/data_files/all_group_plane_fchk_split_images_ters/7492.npz'
data = np.load(npz_file)

cube = data['spectrums']
rows, cols, bands = cube.shape

# %%
bands
# Out:
# 40

# %%
data.files
# Out:
# ['atom_pos', 'atomic_numbers', 'x_pos', 'y_pos', 'frequencies', 'spectrums']
