# %%
import numpy as np
import glob

# %%
def read_xyz(file_path):
    """
    Reads an .xyz file and returns atom symbols and coordinates.
    
    Args:
        file_path (str): Path to the .xyz file.
    
    Returns:
        tuple: (list of atom symbols, NumPy array of coordinates).
    """
    with open(file_path, 'r') as f:
        lines = f.readlines()
        num_atoms = int(lines[0].strip())
        # Skip the comment line (line 2)
        atoms = []
        coords = []
        for line in lines[2:2 + num_atoms]:
            parts = line.split()
            atoms.append(parts[0])
            coords.append([float(parts[1]), float(parts[2]), float(parts[3])])
        return atoms, np.array(coords)

def center_coordinates(coords):
    """
    Centers the coordinates by subtracting the centroid.
    
    Args:
        coords (np.ndarray): Array of shape (n_atoms, 3) with x, y, z coordinates.
    
    Returns:
        np.ndarray: Centered coordinates.
    """
    centroid = np.mean(coords, axis=0)
    return coords - centroid

def perform_pca(coords):
    """
    Performs PCA on the coordinates to find principal axes.
    
    Args:
        coords (np.ndarray): Centilidade coordinates.
    
    Returns:
        tuple: (eigenvalues, eigenvectors) sorted by eigenvalues in descending order.
    """
    cov_matrix = np.cov(coords.T)
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
    # Sort eigenvalues and eigenvectors in descending order
    idx = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[idx]
    eigenvectors = eigenvectors[:, idx]
    return eigenvalues, eigenvectors

def construct_rotation_matrix(eigenvectors):
    """
    Constructs a rotation matrix to align the principal axes with standard axes.
    
    Args:
        eigenvectors (np.ndarray): Matrix with eigenvectors as columns.
    
    Returns:
        np.ndarray: Rotation matrix (transpose of eigenvectors).
    """
    return eigenvectors.T

def rotate_coordinates(coords, rotation_matrix):
    """
    Rotates the coordinates using the rotation matrix.
    
    Args:
        coords (np.ndarray): Centered coordinates.
        rotation_matrix (np.ndarray): Rotation matrix.
    
    Returns:
        np.ndarray: Rotated coordinates.
    """
    return np.dot(coords, rotation_matrix.T)

def write_xyz(file_path, atoms, coords):
    """
    Writes atom symbols and coordinates to a new .xyz file.
    
    Args:
        file_path (str): Path to the output .xyz file.
        atoms (list): List of atom symbols.
        coords (np.ndarray): Array of rotated coordinates.
    """
    with open(file_path, 'w') as f:
        f.write(f"{len(atoms)}\n")
        f.write("Molecule rotated to XY-plane\n")
        for atom, coord in zip(atoms, coords):
            f.write(f"{atom} {coord[0]:.6f} {coord[1]:.6f} {coord[2]:.6f}\n")

def process_file(input_path, output_path):
    """
    Processes a single .xyz file: reads, rotates, and writes the result.
    
    Args:
        input_path (str): Path to the input .xyz file.
        output_path (str): Path to the output .xyz file.
    """
    # Read the file
    atoms, coords = read_xyz(input_path)
    
    # Center the coordinates
    centered_coords = center_coordinates(coords)
    
    # Perform PCA
    eigenvalues, eigenvectors = perform_pca(centered_coords)
    
    # Construct rotation matrix
    rotation_matrix = construct_rotation_matrix(eigenvectors)
    
    # Rotate coordinates
    rotated_coords = rotate_coordinates(centered_coords, rotation_matrix)
    
    # Write to new file
    write_xyz(output_path, atoms, rotated_coords)

def main(directory):
    """
    Processes all .xyz files in the specified directory.
    
    Args:
        directory (str): Path to the directory containing .xyz files.
    """
    for input_path in glob.glob(f"{directory}/*.xyz"):
        output_path = input_path.replace(".xyz", "_rotated.xyz")
        print(f"Processing {input_path} -> {output_path}")
        process_file(input_path, output_path)

if __name__ == "__main__":
    # Replace with the actual path to your directory containing .xyz files
    main("path/to/your/directory")

# %%
import numpy as np
import glob
import os

def compute_planarity_ratio(atom_pos):
    """
    Compute the planarity ratio of a molecule based on its atomic positions.
    Returns a value between 0 and 1, where 1 is perfectly planar.
    """
    # Verify atom_pos is a 2D array with shape (n_atoms, 3)
    if len(atom_pos.shape) != 2 or atom_pos.shape[1] != 3:
        raise ValueError("atom_pos must be a 2D array with shape (n_atoms, 3)")
    
    # Center the coordinates around the origin
    centroid = np.mean(atom_pos, axis=0)
    centered_coords = atom_pos - centroid
    
    # Compute the covariance matrix
    cov_matrix = np.cov(centered_coords, rowvar=False)
    
    # Compute eigenvalues of the covariance matrix (ascending order)
    eigenvalues = np.linalg.eigh(cov_matrix)[0]
    
    # Sort eigenvalues in descending order
    eigenvalues = sorted(eigenvalues, reverse=True)
    
    # Compute planarity ratio: (sum of two largest eigenvalues) / total variance
    total_variance = sum(eigenvalues)
    if total_variance == 0:
        return 1.0  # All atoms at the same point (trivially planar)
    planarity_ratio = (eigenvalues[0] + eigenvalues[1]) / total_variance
    return planarity_ratio

def find_planar_molecules(directory, threshold=0.9):
    """
    Identify .npz files in the directory with molecules meeting the planarity threshold.
    Prints the file names that satisfy the condition.
    """
    # Get list of all .npz files in the directory
    npz_files = glob.glob(f"{directory}/*.npz")
    names = []  # To store file names, as in your snippet
    
    print(f"Checking for molecules at least {threshold*100}% planar:")
    count = 0
    for npz_file in npz_files:
        # Append the file name, matching your snippet
        names.append(os.path.basename(npz_file))
        
        # Load the .npz file and extract data, as per your example
        try:
            with np.load(npz_file) as data:
                atom_pos = data['atom_pos']
                # You can also access these if needed later:
                # atomic_numbers = data['atomic_numbers']
                # frequencies = data['frequencies']
                # spectrums = data['spectrums']
            
            # Compute planarity ratio
            ratio = compute_planarity_ratio(atom_pos)
            
            # Check if the molecule meets the planarity threshold
            if ratio >= threshold:
                print(os.path.basename(npz_file))
                count += 1
                
        except Exception as e:
            print(f"Error processing {os.path.basename(npz_file)}: {e}")

    print(f"Found {count} molecules meeting the planarity threshold.")

# Example usage
if __name__ == "__main__":
    # Replace with your directory containing .npz files
    directory = "/scratch/phys/sin/sethih1/data_files/balanced_group"
    
    # Set the planarity threshold (e.g., 0.9 for 90% planar)
    threshold = 1  # Adjust this as needed
    
    find_planar_molecules(directory, threshold)
# Out:
# Checking for molecules at least 100% planar:
# 24530.npz
# 123195.npz
# 142488.npz
# 115034.npz
# 945.npz
# 6350.npz
# 947.npz
# 62317.npz
# 140063.npz
# 67520.npz
# 948.npz
# 24529.npz
# Found 12 molecules meeting the planarity threshold.

# %%
# Example usage
if __name__ == "__main__":
    # Replace with your directory containing .npz files
    directory = "/scratch/phys/sin/sethih1/data_files/first_group_images"
    
    # Set the planarity threshold (e.g., 0.9 for 90% planar)
    threshold = 1  # Adjust this as needed
    
    find_planar_molecules(directory, threshold)
# Out:
# Checking for molecules at least 100% planar:
# 160438_0.npz
# 104752_0.npz
# 62317_0.npz
# 123083_0.npz
# 11199_0.npz
# 6325_0.npz
# 24602_0.npz
# Found 7 molecules meeting the planarity threshold.

# %%
# Example usage
if __name__ == "__main__":
    # Replace with your directory containing .npz files
    directory = "/scratch/phys/sin/sethih1/data_files/second_group_images"
    
    # Set the planarity threshold (e.g., 0.9 for 90% planar)
    threshold = 1  # Adjust this as needed
    
    find_planar_molecules(directory, threshold)
# Out:
# Checking for molecules at least 100% planar:
# 947_0.npz
# 280_0.npz
# 281_0.npz
# 67520_0.npz
# 123178_0.npz
# 24529_0.npz
# 139859_0.npz
# 138112_0.npz
# 783_0.npz
# 139505_0.npz
# 119388_0.npz
# 24823_0.npz
# 142488_0.npz
# 115034_0.npz
# 123195_0.npz
# 105142_0.npz
# 137677_0.npz
# 540_0.npz
# 6350_0.npz
# 948_0.npz
# 945_0.npz
# 136069_0.npz
# 140063_0.npz
# 768_0.npz
# 138825_0.npz
# 24530_0.npz
# 137676_0.npz
# 962_0.npz
# 9999_0.npz
# Found 29 molecules meeting the planarity threshold.

# %%
# Example usage
if __name__ == "__main__":
    # Replace with your directory containing .npz files
    directory = "/scratch/phys/sin/sethih1/data_files/all_group_images_new"
    
    # Set the planarity threshold (e.g., 0.9 for 90% planar)
    threshold = 0.999  # Adjust this as needed
    
    find_planar_molecules(directory, threshold)
# Out:
# Checking for molecules at least 99.9% planar:
# 764.npz
# 33776.npz
# 19.npz
# 78847.npz
# 192303.npz
# 19914.npz
# 10435.npz
# 191078.npz
# 15875.npz
# 137676.npz
# 6846.npz
# 1491.npz
# 9222.npz
# 456.npz
# 7971.npz
# 95303.npz
# 15863.npz
# 27492.npz
# 92970.npz
# 68401.npz
# 67126.npz
# 69318.npz
# 136679.npz
# 96194.npz
# 10366.npz
# 151097.npz
# 68442.npz
# 4649.npz
# 214615.npz
# 133922.npz
# 237859.npz
# 9338.npz
# 7492.npz
# 14101.npz
# 96389.npz
# 137009.npz
# 123419.npz
# 126347.npz
# 153669.npz
# 72914.npz
# 8784.npz
# 202937.npz
# 11473.npz
# 141184.npz
# 77987.npz
# 88025.npz
# 1456.npz
# 24530.npz
# 66921.npz
# 9231.npz
# 14526.npz
# 119218.npz
# 12087.npz
# 74115.npz
# 6275.npz
# 164592.npz
# 214301.npz
# 162804.npz
# 249592.npz
# 230976.npz
# 247394.npz
# 88085.npz
# 1057.npz
# 187896.npz
# 10268.npz
# 83191.npz
# 21119.npz
# 84684.npz
# 6998.npz
# 247543.npz
# 162542.npz
# 219401.npz
# 220188.npz
# 209813.npz
# 169306.npz
# 11089.npz
# 9226.npz
# 26130.npz
# 136601.npz
# 90070.npz
# 87759.npz
# 24955.npz
# 68514.npz
# 20467.npz
# 79470.npz
# 228506.npz
# 69257.npz
# 72924.npz
# 202767.npz
# 124218.npz
# 110064.npz
# 139859.npz
# 72926.npz
# 72766.npz
# 149137.npz
# 84121.npz
# 12792.npz
# 145773.npz
# 136085.npz
# 32362.npz
# 222902.npz
# 220711.npz
# 61009.npz
# 156602.npz
# 10347.npz
# 13219.npz
# 12828.npz
# 96695.npz
# 938.npz
# 231555.npz
# 65531.npz
# 155432.npz
# 11901.npz
# 7047.npz
# 18606.npz
# 8405.npz
# 101030.npz
# 12088.npz
# 10331.npz
# 10667.npz
# 77081.npz
# 13854.npz
# 96580.npz
# 6864.npz
# 81449.npz
# 12076.npz
# 1043.npz
# 137973.npz
# 11375.npz
# 8024.npz
# 12577.npz
# 249778.npz
# 79510.npz
# 281.npz
# 61208.npz
# 68099.npz
# 238581.npz
# 795.npz
# 165586.npz
# 139183.npz
# 227928.npz
# 243453.npz
# 10392.npz
# 7006.npz
# 80006.npz
# Found 1300 molecules meeting the planarity threshold.

# %%
import numpy as np
import glob
import os
import shutil  # For copying files

def compute_planarity_ratio(atom_pos):
    """
    Compute the planarity ratio of a molecule based on its atomic positions.
    Returns a value between 0 and 1, where 1 is perfectly planar.
    """
    # Verify atom_pos is a 2D array with shape (n_atoms, 3)
    if len(atom_pos.shape) != 2 or atom_pos.shape[1] != 3:
        raise ValueError("atom_pos must be a 2D array with shape (n_atoms, 3)")
    
    # Center the coordinates around the origin
    centroid = np.mean(atom_pos, axis=0)
    centered_coords = atom_pos - centroid
    
    # Compute the covariance matrix
    cov_matrix = np.cov(centered_coords, rowvar=False)
    
    # Compute eigenvalues of the covariance matrix (ascending order)
    eigenvalues = np.linalg.eigh(cov_matrix)[0]
    
    # Sort eigenvalues in descending order
    eigenvalues = sorted(eigenvalues, reverse=True)
    
    # Compute planarity ratio: (sum of two largest eigenvalues) / total variance
    total_variance = sum(eigenvalues)
    if total_variance == 0:
        return 1.0  # All atoms at the same point (trivially planar)
    planarity_ratio = (eigenvalues[0] + eigenvalues[1]) / total_variance
    return planarity_ratio

def copy_planar_molecules(source_directory, dest_directory, threshold=0.9):
    """
    Identify .npz files in the source_directory with molecules meeting the planarity threshold,
    and copy them to the dest_directory.
    """
    # Create the destination directory if it doesn't exist
    os.makedirs(dest_directory, exist_ok=True)
    
    # Get list of all .npz files in the source directory
    npz_files = glob.glob(os.path.join(source_directory, "*.npz"))
    
    print(f"Copying molecules at least {threshold*100}% planar from {source_directory} to {dest_directory}:")
    count = 0
    for npz_file in npz_files:
        try:
            with np.load(npz_file) as data:
                atom_pos = data['atom_pos']
            
            # Compute planarity ratio
            ratio = compute_planarity_ratio(atom_pos)
            
            # Check if the molecule meets the planarity threshold
            if ratio >= threshold:
                dest_path = os.path.join(dest_directory, os.path.basename(npz_file))
                shutil.copy2(npz_file, dest_path)
                print(f"Copied: {os.path.basename(npz_file)} (ratio: {ratio:.3f})")
                count += 1
                
        except Exception as e:
            print(f"Error processing {os.path.basename(npz_file)}: {e}")

    print(f"Copied {count} molecules meeting the planarity threshold.")

# Example usage
if __name__ == "__main__":
    # Replace these with your directories
    source_directory = "/scratch/phys/sin/sethih1/data_files/second_group_images_256"
    dest_directory = "/scratch/phys/sin/sethih1/data_files/planar_molecules_256"
    
    # Set the planarity threshold (e.g., 0.999 for 99.9% planar)
    threshold = 0.999  # Adjust this as needed
    
    copy_planar_molecules(source_directory, dest_directory, threshold)
# Out:
# Copying molecules at least 99.9% planar from /scratch/phys/sin/sethih1/data_files/second_group_images_256 to /scratch/phys/sin/sethih1/data_files/planar_molecules_256:
# Copied: 764.npz (ratio: 1.000)
# Copied: 33776.npz (ratio: 1.000)
# Copied: 19.npz (ratio: 1.000)
# Copied: 78847.npz (ratio: 1.000)
# Copied: 10435.npz (ratio: 1.000)
# Copied: 137676.npz (ratio: 1.000)
# Copied: 1491.npz (ratio: 1.000)
# Copied: 9222.npz (ratio: 1.000)
# Copied: 7971.npz (ratio: 1.000)
# Copied: 95303.npz (ratio: 1.000)
# Copied: 15863.npz (ratio: 1.000)
# Copied: 92970.npz (ratio: 1.000)
# Copied: 67126.npz (ratio: 1.000)
# Copied: 69318.npz (ratio: 1.000)
# Copied: 136679.npz (ratio: 1.000)
# Copied: 96194.npz (ratio: 1.000)
# Copied: 151097.npz (ratio: 1.000)
# Copied: 68442.npz (ratio: 1.000)
# Copied: 133922.npz (ratio: 1.000)
# Copied: 237859.npz (ratio: 0.999)
# Copied: 9338.npz (ratio: 1.000)
# Copied: 14101.npz (ratio: 1.000)
# Copied: 96389.npz (ratio: 1.000)
# Copied: 137009.npz (ratio: 1.000)
# Copied: 123419.npz (ratio: 1.000)
# Copied: 126347.npz (ratio: 1.000)
# Copied: 153669.npz (ratio: 1.000)
# Copied: 72914.npz (ratio: 1.000)
# Copied: 8784.npz (ratio: 1.000)
# Copied: 141184.npz (ratio: 1.000)
# Copied: 77987.npz (ratio: 1.000)
# Copied: 24530.npz (ratio: 1.000)
# Copied: 66921.npz (ratio: 1.000)
# Copied: 14526.npz (ratio: 1.000)
# Copied: 119218.npz (ratio: 1.000)
# Copied: 74115.npz (ratio: 1.000)
# Copied: 164592.npz (ratio: 1.000)
# Copied: 214301.npz (ratio: 1.000)
# Copied: 162804.npz (ratio: 1.000)
# Copied: 249592.npz (ratio: 1.000)
# Copied: 230976.npz (ratio: 1.000)
# Copied: 247394.npz (ratio: 1.000)
# Copied: 1057.npz (ratio: 1.000)
# Copied: 187896.npz (ratio: 1.000)
# Copied: 10268.npz (ratio: 1.000)
# Copied: 83191.npz (ratio: 1.000)
# Copied: 21119.npz (ratio: 1.000)
# Copied: 6998.npz (ratio: 1.000)
# Copied: 247543.npz (ratio: 1.000)
# Copied: 162542.npz (ratio: 1.000)
# Copied: 219401.npz (ratio: 1.000)
# Copied: 220188.npz (ratio: 1.000)
# Copied: 209813.npz (ratio: 1.000)
# Copied: 11089.npz (ratio: 1.000)
# Copied: 9226.npz (ratio: 1.000)
# Copied: 26130.npz (ratio: 1.000)
# Copied: 90070.npz (ratio: 1.000)
# Copied: 87759.npz (ratio: 1.000)
# Copied: 24955.npz (ratio: 1.000)
# Copied: 68514.npz (ratio: 1.000)
# Copied: 20467.npz (ratio: 1.000)
# Copied: 79470.npz (ratio: 1.000)
# Copied: 228506.npz (ratio: 1.000)
# Copied: 69257.npz (ratio: 1.000)
# Copied: 202767.npz (ratio: 1.000)
# Copied: 139859.npz (ratio: 1.000)
# Copied: 72766.npz (ratio: 1.000)
# Copied: 10613.npz (ratio: 1.000)
# Copied: 73268.npz (ratio: 1.000)
# Copied: 69688.npz (ratio: 1.000)
# Copied: 146529.npz (ratio: 1.000)
# Copied: 75733.npz (ratio: 1.000)
# Copied: 197266.npz (ratio: 1.000)
# Copied: 10339.npz (ratio: 1.000)
# Copied: 100698.npz (ratio: 1.000)
# Copied: 77230.npz (ratio: 1.000)
# Copied: 148675.npz (ratio: 1.000)
# Copied: 16463.npz (ratio: 1.000)
# Copied: 69319.npz (ratio: 1.000)
# Copied: 78346.npz (ratio: 1.000)
# Copied: 190119.npz (ratio: 1.000)
# Copied: 87065.npz (ratio: 1.000)
# Copied: 280.npz (ratio: 1.000)
# Copied: 136411.npz (ratio: 1.000)
# Copied: 95516.npz (ratio: 1.000)
# Copied: 153574.npz (ratio: 1.000)
# Copied: 12584.npz (ratio: 1.000)
# Copied: 128646.npz (ratio: 1.000)
# Copied: 242445.npz (ratio: 1.000)
# Copied: 154772.npz (ratio: 1.000)
# Copied: 25452.npz (ratio: 1.000)
# Copied: 10378.npz (ratio: 1.000)
# Copied: 36328.npz (ratio: 1.000)
# Copied: 135264.npz (ratio: 1.000)
# Copied: 76427.npz (ratio: 1.000)
# Copied: 139129.npz (ratio: 1.000)
# Copied: 10028.npz (ratio: 1.000)
# Copied: 188071.npz (ratio: 1.000)
# Copied: 100643.npz (ratio: 0.999)
# Copied: 967.npz (ratio: 1.000)
# Copied: 114596.npz (ratio: 1.000)
# Copied: 77148.npz (ratio: 1.000)
# Copied: 46389.npz (ratio: 1.000)
# Copied: 248832.npz (ratio: 1.000)
# Copied: 173747.npz (ratio: 1.000)
# Copied: 95201.npz (ratio: 1.000)
# Copied: 101920.npz (ratio: 1.000)
# Copied: 73172.npz (ratio: 1.000)
# Copied: 76923.npz (ratio: 1.000)
# Copied: 234287.npz (ratio: 1.000)
# Copied: 135441.npz (ratio: 1.000)
# Copied: 22208.npz (ratio: 1.000)
# Copied: 22634.npz (ratio: 1.000)
# Copied: 119315.npz (ratio: 1.000)
# Copied: 61132.npz (ratio: 1.000)
# Copied: 123195.npz (ratio: 1.000)
# Copied: 70715.npz (ratio: 1.000)
# Copied: 229771.npz (ratio: 1.000)
# Copied: 944.npz (ratio: 1.000)
# Copied: 249770.npz (ratio: 1.000)
# Copied: 119208.npz (ratio: 1.000)
# Copied: 101984.npz (ratio: 1.000)
# Copied: 7501.npz (ratio: 1.000)
# Copied: 94081.npz (ratio: 1.000)
# Copied: 12143.npz (ratio: 1.000)
# Copied: 11865.npz (ratio: 1.000)
# Copied: 191109.npz (ratio: 1.000)
# Copied: 24823.npz (ratio: 1.000)
# Copied: 123991.npz (ratio: 1.000)
# Copied: 141717.npz (ratio: 1.000)
# Copied: 86.npz (ratio: 1.000)
# Copied: 78419.npz (ratio: 1.000)
# Copied: 68139.npz (ratio: 1.000)
# Copied: 18639.npz (ratio: 1.000)
# Copied: 109898.npz (ratio: 1.000)
# Copied: 69712.npz (ratio: 1.000)
# Copied: 123243.npz (ratio: 1.000)
# Copied: 239342.npz (ratio: 0.999)
# Copied: 11374.npz (ratio: 1.000)
# Copied: 79.npz (ratio: 1.000)
# Copied: 67519.npz (ratio: 1.000)
# Copied: 67517.npz (ratio: 1.000)
# Copied: 1046.npz (ratio: 1.000)
# Copied: 6145.npz (ratio: 1.000)
# Copied: 140072.npz (ratio: 1.000)
# Copied: 27513.npz (ratio: 1.000)
# Copied: 76428.npz (ratio: 1.000)
# Copied: 126590.npz (ratio: 1.000)
# Copied: 27843.npz (ratio: 1.000)
# Copied: 75571.npz (ratio: 1.000)
# Copied: 182090.npz (ratio: 1.000)
# Copied: 14312.npz (ratio: 1.000)
# Copied: 28.npz (ratio: 1.000)
# Copied: 8665.npz (ratio: 1.000)
# Copied: 200456.npz (ratio: 1.000)
# Copied: 232524.npz (ratio: 1.000)
# Copied: 43157.npz (ratio: 1.000)
# Copied: 119388.npz (ratio: 1.000)
# Copied: 68129.npz (ratio: 1.000)
# Copied: 147399.npz (ratio: 1.000)
# Copied: 78389.npz (ratio: 1.000)
# Copied: 17608.npz (ratio: 1.000)
# Copied: 138208.npz (ratio: 1.000)
# Copied: 120463.npz (ratio: 1.000)
# Copied: 69256.npz (ratio: 1.000)
# Copied: 760.npz (ratio: 1.000)
# Copied: 138739.npz (ratio: 1.000)
# Copied: 18750.npz (ratio: 1.000)
# Copied: 167570.npz (ratio: 1.000)
# Copied: 234722.npz (ratio: 1.000)
# Copied: 980.npz (ratio: 1.000)
# Copied: 713.npz (ratio: 1.000)
# Copied: 152422.npz (ratio: 1.000)
# Copied: 243601.npz (ratio: 1.000)
# Copied: 181880.npz (ratio: 1.000)
# Copied: 240601.npz (ratio: 1.000)
# Copied: 2331.npz (ratio: 1.000)
# Copied: 12032.npz (ratio: 1.000)
# Copied: 121274.npz (ratio: 1.000)
# Copied: 20707.npz (ratio: 1.000)
# Copied: 99477.npz (ratio: 1.000)
# Copied: 65052.npz (ratio: 1.000)
# Copied: 151398.npz (ratio: 1.000)
# Copied: 10250.npz (ratio: 1.000)
# Copied: 7506.npz (ratio: 1.000)
# Copied: 138764.npz (ratio: 1.000)
# Copied: 76559.npz (ratio: 1.000)
# Copied: 11760.npz (ratio: 1.000)
# Copied: 1044.npz (ratio: 1.000)
# Copied: 4807.npz (ratio: 1.000)
# Copied: 67501.npz (ratio: 1.000)
# Copied: 219130.npz (ratio: 1.000)
# Copied: 70740.npz (ratio: 1.000)
# Copied: 236528.npz (ratio: 1.000)
# Copied: 171225.npz (ratio: 1.000)
# Copied: 85301.npz (ratio: 1.000)
# Copied: 79619.npz (ratio: 1.000)
# Copied: 134173.npz (ratio: 1.000)
# Copied: 69395.npz (ratio: 1.000)
# Copied: 68141.npz (ratio: 1.000)
# Copied: 7956.npz (ratio: 1.000)
# Copied: 235303.npz (ratio: 1.000)
# Copied: 124504.npz (ratio: 1.000)
# Copied: 76868.npz (ratio: 1.000)
# Copied: 21275.npz (ratio: 1.000)
# Copied: 142424.npz (ratio: 1.000)
# Copied: 247031.npz (ratio: 1.000)
# Copied: 142488.npz (ratio: 1.000)
# Copied: 145786.npz (ratio: 1.000)
# Copied: 237410.npz (ratio: 1.000)
# Copied: 7431.npz (ratio: 1.000)
# Copied: 78210.npz (ratio: 1.000)
# Copied: 145813.npz (ratio: 1.000)
# Copied: 173173.npz (ratio: 1.000)
# Copied: 66196.npz (ratio: 1.000)
# Copied: 75740.npz (ratio: 0.999)
# Copied: 66520.npz (ratio: 1.000)
# Copied: 1047.npz (ratio: 1.000)
# Copied: 136069.npz (ratio: 1.000)
# Copied: 78968.npz (ratio: 1.000)
# Copied: 66012.npz (ratio: 1.000)
# Copied: 245915.npz (ratio: 1.000)
# Copied: 13394.npz (ratio: 1.000)
# Copied: 231328.npz (ratio: 1.000)
# Copied: 7493.npz (ratio: 1.000)
# Copied: 72073.npz (ratio: 1.000)
# Copied: 142312.npz (ratio: 1.000)
# Copied: 242011.npz (ratio: 1.000)
# Copied: 7321.npz (ratio: 1.000)
# Copied: 69117.npz (ratio: 1.000)
# Copied: 67504.npz (ratio: 1.000)
# Copied: 1923.npz (ratio: 1.000)
# Copied: 70729.npz (ratio: 1.000)
# Copied: 136328.npz (ratio: 1.000)
# Copied: 140920.npz (ratio: 1.000)
# Copied: 136928.npz (ratio: 1.000)
# Copied: 230047.npz (ratio: 1.000)
# Copied: 7416.npz (ratio: 1.000)
# Copied: 16122.npz (ratio: 1.000)
# Copied: 78502.npz (ratio: 1.000)
# Copied: 75118.npz (ratio: 1.000)
# Copied: 119310.npz (ratio: 1.000)
# Copied: 145018.npz (ratio: 1.000)
# Copied: 101438.npz (ratio: 1.000)
# Copied: 81595.npz (ratio: 1.000)
# Copied: 931.npz (ratio: 1.000)
# Copied: 370.npz (ratio: 1.000)
# Copied: 77552.npz (ratio: 1.000)
# Copied: 102323.npz (ratio: 1.000)
# Copied: 8394.npz (ratio: 1.000)
# Copied: 81210.npz (ratio: 1.000)
# Copied: 7213.npz (ratio: 1.000)
# Copied: 34037.npz (ratio: 1.000)
# Copied: 139144.npz (ratio: 1.000)
# Copied: 186114.npz (ratio: 1.000)
# Copied: 10789.npz (ratio: 1.000)
# Copied: 140071.npz (ratio: 1.000)
# Copied: 189055.npz (ratio: 0.999)
# Copied: 5798.npz (ratio: 1.000)
# Copied: 80322.npz (ratio: 1.000)
# Copied: 146002.npz (ratio: 1.000)
# Copied: 242831.npz (ratio: 1.000)
# Copied: 90614.npz (ratio: 1.000)
# Copied: 241841.npz (ratio: 1.000)
# Copied: 8496.npz (ratio: 1.000)
# Copied: 6969.npz (ratio: 1.000)
# Copied: 10640.npz (ratio: 1.000)
# Copied: 12660.npz (ratio: 1.000)
# Copied: 134668.npz (ratio: 1.000)
# Copied: 187842.npz (ratio: 1.000)
# Copied: 88612.npz (ratio: 1.000)
# Copied: 6108.npz (ratio: 1.000)
# Copied: 7420.npz (ratio: 1.000)
# Copied: 136032.npz (ratio: 1.000)
# Copied: 74667.npz (ratio: 1.000)
# Copied: 100599.npz (ratio: 1.000)
# Copied: 138256.npz (ratio: 1.000)
# Copied: 7845.npz (ratio: 1.000)
# Copied: 152917.npz (ratio: 1.000)
# Copied: 8618.npz (ratio: 1.000)
# Copied: 20765.npz (ratio: 1.000)
# Copied: 9228.npz (ratio: 1.000)
# Copied: 6919.npz (ratio: 1.000)
# Copied: 136089.npz (ratio: 1.000)
# Copied: 176480.npz (ratio: 1.000)
# Copied: 78374.npz (ratio: 1.000)
# Copied: 372.npz (ratio: 1.000)
# Copied: 7452.npz (ratio: 1.000)
# Copied: 338.npz (ratio: 1.000)
# Copied: 5922.npz (ratio: 1.000)
# Copied: 139048.npz (ratio: 1.000)
# Copied: 790.npz (ratio: 1.000)
# Copied: 79027.npz (ratio: 1.000)
# Copied: 193416.npz (ratio: 1.000)
# Copied: 66808.npz (ratio: 1.000)
# Copied: 78934.npz (ratio: 1.000)
# Copied: 142323.npz (ratio: 1.000)
# Copied: 400.npz (ratio: 1.000)
# Copied: 194087.npz (ratio: 1.000)
# Copied: 12276.npz (ratio: 1.000)
# Copied: 64962.npz (ratio: 1.000)
# Copied: 21631.npz (ratio: 1.000)
# Copied: 67541.npz (ratio: 1.000)
# Copied: 240.npz (ratio: 1.000)
# Copied: 143051.npz (ratio: 1.000)
# Copied: 159844.npz (ratio: 1.000)
# Copied: 94365.npz (ratio: 1.000)
# Copied: 167605.npz (ratio: 1.000)
# Copied: 139106.npz (ratio: 1.000)
# Copied: 140409.npz (ratio: 1.000)
# Copied: 123081.npz (ratio: 1.000)
# Copied: 61291.npz (ratio: 1.000)
# Copied: 138350.npz (ratio: 1.000)
# Copied: 15070.npz (ratio: 1.000)
# Copied: 74802.npz (ratio: 1.000)
# Copied: 11373.npz (ratio: 0.999)
# Copied: 149148.npz (ratio: 1.000)
# Copied: 9254.npz (ratio: 1.000)
# Copied: 181501.npz (ratio: 1.000)
# Copied: 143168.npz (ratio: 1.000)
# Copied: 10881.npz (ratio: 1.000)
# Copied: 230282.npz (ratio: 1.000)
# Copied: 115242.npz (ratio: 1.000)
# Copied: 8397.npz (ratio: 1.000)
# Copied: 115034.npz (ratio: 1.000)
# Copied: 144586.npz (ratio: 1.000)
# Copied: 69085.npz (ratio: 1.000)
# Copied: 165106.npz (ratio: 1.000)
# Copied: 138061.npz (ratio: 1.000)
# Copied: 11945.npz (ratio: 1.000)
# Copied: 137963.npz (ratio: 1.000)
# Copied: 20821.npz (ratio: 1.000)
# Copied: 90579.npz (ratio: 1.000)
# Copied: 75944.npz (ratio: 1.000)
# Copied: 155610.npz (ratio: 1.000)
# Copied: 19416.npz (ratio: 1.000)
# Copied: 3469.npz (ratio: 1.000)
# Copied: 77094.npz (ratio: 1.000)
# Copied: 161724.npz (ratio: 1.000)
# Copied: 145421.npz (ratio: 1.000)
# Copied: 73836.npz (ratio: 1.000)
# Copied: 11421.npz (ratio: 1.000)
# Copied: 11378.npz (ratio: 1.000)
# Copied: 16695.npz (ratio: 1.000)
# Copied: 22716.npz (ratio: 1.000)
# Copied: 136784.npz (ratio: 1.000)
# Copied: 945.npz (ratio: 1.000)
# Copied: 9227.npz (ratio: 1.000)
# Copied: 13019.npz (ratio: 1.000)
# Copied: 104994.npz (ratio: 1.000)
# Copied: 102410.npz (ratio: 0.999)
# Copied: 67488.npz (ratio: 1.000)
# Copied: 90301.npz (ratio: 1.000)
# Copied: 69113.npz (ratio: 0.999)
# Copied: 84381.npz (ratio: 1.000)
# Copied: 177065.npz (ratio: 1.000)
# Copied: 37873.npz (ratio: 1.000)
# Copied: 144430.npz (ratio: 1.000)
# Copied: 68255.npz (ratio: 1.000)
# Copied: 137677.npz (ratio: 1.000)
# Copied: 117.npz (ratio: 1.000)
# Copied: 143177.npz (ratio: 1.000)
# Copied: 74730.npz (ratio: 1.000)
# Copied: 76835.npz (ratio: 1.000)
# Copied: 20077.npz (ratio: 1.000)
# Copied: 96685.npz (ratio: 1.000)
# Copied: 77887.npz (ratio: 1.000)
# Copied: 19103.npz (ratio: 1.000)
# Copied: 119924.npz (ratio: 1.000)
# Copied: 23069.npz (ratio: 1.000)
# Copied: 75395.npz (ratio: 1.000)
# Copied: 246683.npz (ratio: 1.000)
# Copied: 7671.npz (ratio: 1.000)
# Copied: 67507.npz (ratio: 1.000)
# Copied: 13244.npz (ratio: 1.000)
# Copied: 6043.npz (ratio: 1.000)
# Copied: 11985.npz (ratio: 1.000)
# Copied: 69135.npz (ratio: 1.000)
# Copied: 70504.npz (ratio: 1.000)
# Copied: 76974.npz (ratio: 1.000)
# Copied: 12222.npz (ratio: 1.000)
# Copied: 24358.npz (ratio: 1.000)
# Copied: 154770.npz (ratio: 1.000)
# Copied: 74217.npz (ratio: 1.000)
# Copied: 186605.npz (ratio: 1.000)
# Copied: 229932.npz (ratio: 1.000)
# Copied: 69980.npz (ratio: 1.000)
# Copied: 28532.npz (ratio: 1.000)
# Copied: 6350.npz (ratio: 1.000)
# Copied: 540.npz (ratio: 1.000)
# Copied: 123178.npz (ratio: 1.000)
# Copied: 22680.npz (ratio: 1.000)
# Copied: 90762.npz (ratio: 1.000)
# Copied: 84686.npz (ratio: 1.000)
# Copied: 73026.npz (ratio: 1.000)
# Copied: 74280.npz (ratio: 1.000)
# Copied: 72917.npz (ratio: 1.000)
# Copied: 9230.npz (ratio: 1.000)
# Copied: 6946.npz (ratio: 1.000)
# Copied: 190.npz (ratio: 1.000)
# Copied: 70734.npz (ratio: 1.000)
# Copied: 83641.npz (ratio: 1.000)
# Copied: 137865.npz (ratio: 1.000)
# Copied: 67956.npz (ratio: 1.000)
# Copied: 224980.npz (ratio: 1.000)
# Copied: 10701.npz (ratio: 1.000)
# Copied: 76164.npz (ratio: 1.000)
# Copied: 68153.npz (ratio: 1.000)
# Copied: 113400.npz (ratio: 1.000)
# Copied: 142400.npz (ratio: 1.000)
# Copied: 234355.npz (ratio: 0.999)
# Copied: 7045.npz (ratio: 1.000)
# Copied: 81456.npz (ratio: 1.000)
# Copied: 98373.npz (ratio: 1.000)
# Copied: 136076.npz (ratio: 1.000)
# Copied: 120144.npz (ratio: 1.000)
# Copied: 170404.npz (ratio: 1.000)
# Copied: 61301.npz (ratio: 1.000)
# Copied: 75420.npz (ratio: 0.999)
# Copied: 82587.npz (ratio: 1.000)
# Copied: 77840.npz (ratio: 1.000)
# Copied: 6882.npz (ratio: 1.000)
# Copied: 164848.npz (ratio: 1.000)
# Copied: 9208.npz (ratio: 1.000)
# Copied: 72670.npz (ratio: 1.000)
# Copied: 138825.npz (ratio: 1.000)
# Copied: 6809.npz (ratio: 1.000)
# Copied: 159639.npz (ratio: 1.000)
# Copied: 9259.npz (ratio: 1.000)
# Copied: 128038.npz (ratio: 1.000)
# Copied: 73278.npz (ratio: 1.000)
# Copied: 136705.npz (ratio: 1.000)
# Copied: 123097.npz (ratio: 1.000)
# Copied: 9257.npz (ratio: 1.000)
# Copied: 150215.npz (ratio: 1.000)
# Copied: 9223.npz (ratio: 1.000)
# Copied: 123214.npz (ratio: 1.000)
# Copied: 6581.npz (ratio: 1.000)
# Copied: 228824.npz (ratio: 1.000)
# Copied: 114683.npz (ratio: 1.000)
# Copied: 10971.npz (ratio: 1.000)
# Copied: 160949.npz (ratio: 1.000)
# Copied: 136071.npz (ratio: 1.000)
# Copied: 67050.npz (ratio: 1.000)
# Copied: 9210.npz (ratio: 1.000)
# Copied: 81484.npz (ratio: 1.000)
# Copied: 189249.npz (ratio: 1.000)
# Copied: 98579.npz (ratio: 1.000)
# Copied: 7729.npz (ratio: 1.000)
# Copied: 93177.npz (ratio: 1.000)
# Copied: 134719.npz (ratio: 1.000)
# Copied: 123295.npz (ratio: 1.000)
# Copied: 7505.npz (ratio: 1.000)
# Copied: 72759.npz (ratio: 1.000)
# Copied: 224573.npz (ratio: 0.999)
# Copied: 74170.npz (ratio: 1.000)
# Copied: 247194.npz (ratio: 1.000)
# Copied: 191671.npz (ratio: 1.000)
# Copied: 12.npz (ratio: 1.000)
# Copied: 30.npz (ratio: 1.000)
# Copied: 136327.npz (ratio: 1.000)
# Copied: 150946.npz (ratio: 1.000)
# Copied: 12583.npz (ratio: 1.000)
# Copied: 13606.npz (ratio: 1.000)
# Copied: 88439.npz (ratio: 1.000)
# Copied: 85340.npz (ratio: 1.000)
# Copied: 146119.npz (ratio: 1.000)
# Copied: 227597.npz (ratio: 1.000)
# Copied: 4604.npz (ratio: 1.000)
# Copied: 694.npz (ratio: 1.000)
# Copied: 9220.npz (ratio: 1.000)
# Copied: 14272.npz (ratio: 1.000)
# Copied: 154771.npz (ratio: 1.000)
# Copied: 14080.npz (ratio: 1.000)
# Copied: 219132.npz (ratio: 1.000)
# Copied: 170265.npz (ratio: 1.000)
# Copied: 12473.npz (ratio: 1.000)
# Copied: 12720.npz (ratio: 1.000)
# Copied: 181887.npz (ratio: 1.000)
# Copied: 136070.npz (ratio: 1.000)
# Copied: 101445.npz (ratio: 1.000)
# Copied: 227927.npz (ratio: 1.000)
# Copied: 236347.npz (ratio: 1.000)
# Copied: 63112.npz (ratio: 1.000)
# Copied: 7054.npz (ratio: 1.000)
# Copied: 24259.npz (ratio: 1.000)
# Copied: 157827.npz (ratio: 0.999)
# Copied: 541.npz (ratio: 1.000)
# Copied: 18208.npz (ratio: 1.000)
# Copied: 61526.npz (ratio: 1.000)
# Copied: 6947.npz (ratio: 1.000)
# Copied: 25796.npz (ratio: 1.000)
# Copied: 151011.npz (ratio: 1.000)
# Copied: 9955.npz (ratio: 0.999)
# Copied: 70956.npz (ratio: 1.000)
# Copied: 22523.npz (ratio: 1.000)
# Copied: 18169.npz (ratio: 1.000)
# Copied: 712.npz (ratio: 1.000)
# Copied: 50578.npz (ratio: 1.000)
# Copied: 9255.npz (ratio: 1.000)
# Copied: 978.npz (ratio: 0.999)
# Copied: 11379.npz (ratio: 0.999)
# Copied: 240909.npz (ratio: 0.999)
# Copied: 13037.npz (ratio: 1.000)
# Copied: 144045.npz (ratio: 1.000)
# Copied: 1750.npz (ratio: 1.000)
# Copied: 25352.npz (ratio: 1.000)
# Copied: 167527.npz (ratio: 1.000)
# Copied: 4650.npz (ratio: 1.000)
# Copied: 137595.npz (ratio: 1.000)
# Copied: 74281.npz (ratio: 1.000)
# Copied: 124358.npz (ratio: 1.000)
# Copied: 68443.npz (ratio: 0.999)
# Copied: 71601.npz (ratio: 1.000)
# Copied: 137630.npz (ratio: 1.000)
# Copied: 10443.npz (ratio: 1.000)
# Copied: 7913.npz (ratio: 1.000)
# Copied: 72829.npz (ratio: 1.000)
# Copied: 170417.npz (ratio: 1.000)
# Copied: 191105.npz (ratio: 1.000)
# Copied: 9261.npz (ratio: 1.000)
# Copied: 74315.npz (ratio: 0.999)
# Copied: 76967.npz (ratio: 1.000)
# Copied: 73000.npz (ratio: 1.000)
# Copied: 231144.npz (ratio: 1.000)
# Copied: 69574.npz (ratio: 0.999)
# Copied: 1049.npz (ratio: 1.000)
# Copied: 152368.npz (ratio: 1.000)
# Copied: 234594.npz (ratio: 1.000)
# Copied: 947.npz (ratio: 1.000)
# Copied: 202697.npz (ratio: 1.000)
# Copied: 72.npz (ratio: 1.000)
# Copied: 123130.npz (ratio: 1.000)
# Copied: 151481.npz (ratio: 1.000)
# Copied: 75466.npz (ratio: 1.000)
# Copied: 152272.npz (ratio: 1.000)
# Copied: 246513.npz (ratio: 0.999)
# Copied: 10876.npz (ratio: 1.000)
# Copied: 15366.npz (ratio: 1.000)
# Copied: 138191.npz (ratio: 1.000)
# Copied: 79453.npz (ratio: 1.000)
# Copied: 136072.npz (ratio: 1.000)
# Copied: 105142.npz (ratio: 1.000)
# Copied: 162652.npz (ratio: 1.000)
# Copied: 31262.npz (ratio: 1.000)
# Copied: 143912.npz (ratio: 1.000)
# Copied: 246392.npz (ratio: 1.000)
# Copied: 10821.npz (ratio: 1.000)
# Copied: 122074.npz (ratio: 1.000)
# Copied: 69129.npz (ratio: 1.000)
# Copied: 43297.npz (ratio: 1.000)
# Copied: 123210.npz (ratio: 1.000)
# Copied: 66042.npz (ratio: 1.000)
# Copied: 24772.npz (ratio: 0.999)
# Copied: 148589.npz (ratio: 1.000)
# Copied: 123092.npz (ratio: 1.000)
# Copied: 359.npz (ratio: 1.000)
# Copied: 146530.npz (ratio: 1.000)
# Copied: 21940.npz (ratio: 0.999)
# Copied: 46153.npz (ratio: 1.000)
# Copied: 67498.npz (ratio: 1.000)
# Copied: 74858.npz (ratio: 1.000)
# Copied: 77197.npz (ratio: 1.000)
# Copied: 67489.npz (ratio: 1.000)
# Copied: 29244.npz (ratio: 1.000)
# Copied: 219470.npz (ratio: 1.000)
# Copied: 186609.npz (ratio: 0.999)
# Copied: 248383.npz (ratio: 1.000)
# Copied: 68154.npz (ratio: 1.000)
# Copied: 171253.npz (ratio: 1.000)
# Copied: 7847.npz (ratio: 1.000)
# Copied: 10286.npz (ratio: 1.000)
# Copied: 246909.npz (ratio: 1.000)
# Copied: 10367.npz (ratio: 1.000)
# Copied: 6038.npz (ratio: 1.000)
# Copied: 12789.npz (ratio: 1.000)
# Copied: 194430.npz (ratio: 1.000)
# Copied: 141040.npz (ratio: 1.000)
# Copied: 83786.npz (ratio: 1.000)
# Copied: 14512.npz (ratio: 1.000)
# Copied: 67130.npz (ratio: 1.000)
# Copied: 197848.npz (ratio: 1.000)
# Copied: 24255.npz (ratio: 1.000)
# Copied: 307.npz (ratio: 1.000)
# Copied: 171518.npz (ratio: 1.000)
# Copied: 69867.npz (ratio: 1.000)
# Copied: 136086.npz (ratio: 1.000)
# Copied: 97353.npz (ratio: 1.000)
# Copied: 161825.npz (ratio: 1.000)
# Copied: 93187.npz (ratio: 1.000)
# Copied: 138333.npz (ratio: 1.000)
# Copied: 126.npz (ratio: 1.000)
# Copied: 138446.npz (ratio: 1.000)
# Copied: 18496.npz (ratio: 0.999)
# Copied: 90385.npz (ratio: 1.000)
# Copied: 143827.npz (ratio: 1.000)
# Copied: 7978.npz (ratio: 1.000)
# Copied: 136323.npz (ratio: 1.000)
# Copied: 120338.npz (ratio: 1.000)
# Copied: 134974.npz (ratio: 1.000)
# Copied: 12174.npz (ratio: 1.000)
# Copied: 87801.npz (ratio: 1.000)
# Copied: 219633.npz (ratio: 1.000)
# Copied: 11360.npz (ratio: 1.000)
# Copied: 7195.npz (ratio: 1.000)
# Copied: 76758.npz (ratio: 1.000)
# Copied: 14271.npz (ratio: 1.000)
# Copied: 16976.npz (ratio: 1.000)
# Copied: 144650.npz (ratio: 1.000)
# Copied: 75064.npz (ratio: 1.000)
# Copied: 99499.npz (ratio: 1.000)
# Copied: 21208.npz (ratio: 0.999)
# Copied: 13395.npz (ratio: 1.000)
# Copied: 136329.npz (ratio: 1.000)
# Copied: 76432.npz (ratio: 1.000)
# Copied: 6347.npz (ratio: 1.000)
# Copied: 206592.npz (ratio: 1.000)
# Copied: 7449.npz (ratio: 1.000)
# Copied: 7200.npz (ratio: 1.000)
# Copied: 8027.npz (ratio: 1.000)
# Copied: 127115.npz (ratio: 0.999)
# Copied: 136752.npz (ratio: 1.000)
# Copied: 72899.npz (ratio: 1.000)
# Copied: 138172.npz (ratio: 0.999)
# Copied: 203621.npz (ratio: 1.000)
# Copied: 12635.npz (ratio: 1.000)
# Copied: 185765.npz (ratio: 1.000)
# Copied: 10256.npz (ratio: 1.000)
# Copied: 68130.npz (ratio: 1.000)
# Copied: 767.npz (ratio: 1.000)
# Copied: 123139.npz (ratio: 1.000)
# Copied: 7502.npz (ratio: 1.000)
# Copied: 96450.npz (ratio: 1.000)
# Copied: 16807.npz (ratio: 1.000)
# Copied: 17274.npz (ratio: 1.000)
# Copied: 228825.npz (ratio: 1.000)
# Copied: 8530.npz (ratio: 1.000)
# Copied: 28115.npz (ratio: 1.000)
# Copied: 122783.npz (ratio: 1.000)
# Copied: 2953.npz (ratio: 1.000)
# Copied: 85134.npz (ratio: 0.999)
# Copied: 89765.npz (ratio: 1.000)
# Copied: 97251.npz (ratio: 1.000)
# Copied: 70277.npz (ratio: 1.000)
# Copied: 146325.npz (ratio: 1.000)
# Copied: 28961.npz (ratio: 1.000)
# Copied: 73881.npz (ratio: 1.000)
# Copied: 141156.npz (ratio: 1.000)
# Copied: 98231.npz (ratio: 1.000)
# Copied: 7475.npz (ratio: 0.999)
# Copied: 21629.npz (ratio: 1.000)
# Copied: 13401.npz (ratio: 1.000)
# Copied: 67036.npz (ratio: 1.000)
# Copied: 148403.npz (ratio: 0.999)
# Copied: 85146.npz (ratio: 1.000)
# Copied: 13385.npz (ratio: 1.000)
# Copied: 69213.npz (ratio: 1.000)
# Copied: 16376.npz (ratio: 1.000)
# Copied: 1893.npz (ratio: 1.000)
# Copied: 211058.npz (ratio: 1.000)
# Copied: 209041.npz (ratio: 1.000)
# Copied: 186602.npz (ratio: 1.000)
# Copied: 68400.npz (ratio: 1.000)
# Copied: 16258.npz (ratio: 1.000)
# Copied: 88336.npz (ratio: 1.000)
# Copied: 34777.npz (ratio: 1.000)
# Copied: 70951.npz (ratio: 1.000)
# Copied: 181147.npz (ratio: 1.000)
# Copied: 11907.npz (ratio: 1.000)
# Copied: 185633.npz (ratio: 1.000)
# Copied: 93183.npz (ratio: 1.000)
# Copied: 150868.npz (ratio: 1.000)
# Copied: 798.npz (ratio: 1.000)
# Copied: 100608.npz (ratio: 1.000)
# Copied: 148431.npz (ratio: 1.000)
# Copied: 77522.npz (ratio: 1.000)
# Copied: 137779.npz (ratio: 1.000)
# Copied: 11946.npz (ratio: 1.000)
# Copied: 225402.npz (ratio: 1.000)
# Copied: 72758.npz (ratio: 1.000)
# Copied: 44390.npz (ratio: 1.000)
# Copied: 93791.npz (ratio: 1.000)
# Copied: 137711.npz (ratio: 1.000)
# Copied: 96163.npz (ratio: 1.000)
# Copied: 81431.npz (ratio: 1.000)
# Copied: 140063.npz (ratio: 1.000)
# Copied: 94842.npz (ratio: 1.000)
# Copied: 142764.npz (ratio: 1.000)
# Copied: 66171.npz (ratio: 1.000)
# Copied: 76720.npz (ratio: 1.000)
# Copied: 198330.npz (ratio: 1.000)
# Copied: 240609.npz (ratio: 1.000)
# Copied: 11459.npz (ratio: 1.000)
# Copied: 179348.npz (ratio: 1.000)
# Copied: 12994.npz (ratio: 1.000)
# Copied: 67491.npz (ratio: 1.000)
# Copied: 134971.npz (ratio: 1.000)
# Copied: 192724.npz (ratio: 1.000)
# Copied: 69114.npz (ratio: 1.000)
# Copied: 75421.npz (ratio: 1.000)
# Copied: 73142.npz (ratio: 1.000)
# Copied: 12068.npz (ratio: 1.000)
# Copied: 1891.npz (ratio: 1.000)
# Copied: 143970.npz (ratio: 1.000)
# Copied: 21954.npz (ratio: 1.000)
# Copied: 69141.npz (ratio: 1.000)
# Copied: 147522.npz (ratio: 1.000)
# Copied: 230474.npz (ratio: 1.000)
# Copied: 7005.npz (ratio: 1.000)
# Copied: 137650.npz (ratio: 1.000)
# Copied: 239360.npz (ratio: 1.000)
# Copied: 75112.npz (ratio: 1.000)
# Copied: 75389.npz (ratio: 1.000)
# Copied: 7489.npz (ratio: 1.000)
# Copied: 77406.npz (ratio: 0.999)
# Copied: 81636.npz (ratio: 1.000)
# Copied: 21483.npz (ratio: 1.000)
# Copied: 76324.npz (ratio: 1.000)
# Copied: 134582.npz (ratio: 1.000)
# Copied: 783.npz (ratio: 1.000)
# Copied: 7968.npz (ratio: 1.000)
# Copied: 247328.npz (ratio: 0.999)
# Copied: 962.npz (ratio: 1.000)
# Copied: 65125.npz (ratio: 1.000)
# Copied: 101509.npz (ratio: 1.000)
# Copied: 69102.npz (ratio: 1.000)
# Copied: 277.npz (ratio: 1.000)
# Copied: 37583.npz (ratio: 0.999)
# Copied: 211469.npz (ratio: 1.000)
# Copied: 224584.npz (ratio: 1.000)
# Copied: 22601.npz (ratio: 1.000)
# Copied: 137088.npz (ratio: 1.000)
# Copied: 9263.npz (ratio: 1.000)
# Copied: 150927.npz (ratio: 1.000)
# Copied: 1174.npz (ratio: 1.000)
# Copied: 67520.npz (ratio: 1.000)
# Copied: 85494.npz (ratio: 1.000)
# Copied: 78482.npz (ratio: 1.000)
# Copied: 23098.npz (ratio: 1.000)
# Copied: 79130.npz (ratio: 1.000)
# Copied: 120467.npz (ratio: 1.000)
# Copied: 399.npz (ratio: 1.000)
# Copied: 948.npz (ratio: 1.000)
# Copied: 19759.npz (ratio: 1.000)
# Copied: 222670.npz (ratio: 1.000)
# Copied: 141735.npz (ratio: 1.000)
# Copied: 140862.npz (ratio: 1.000)
# Copied: 75570.npz (ratio: 1.000)
# Copied: 27814.npz (ratio: 1.000)
# Copied: 70342.npz (ratio: 1.000)
# Copied: 136879.npz (ratio: 1.000)
# Copied: 145406.npz (ratio: 1.000)
# Copied: 67580.npz (ratio: 1.000)
# Copied: 144853.npz (ratio: 1.000)
# Copied: 225029.npz (ratio: 1.000)
# Copied: 229071.npz (ratio: 1.000)
# Copied: 8029.npz (ratio: 1.000)
# Copied: 11377.npz (ratio: 0.999)
# Copied: 155424.npz (ratio: 1.000)
# Copied: 97512.npz (ratio: 1.000)
# Copied: 135.npz (ratio: 1.000)
# Copied: 1018.npz (ratio: 1.000)
# Copied: 78250.npz (ratio: 1.000)
# Copied: 77593.npz (ratio: 1.000)
# Copied: 40452.npz (ratio: 1.000)
# Copied: 13650.npz (ratio: 1.000)
# Copied: 108854.npz (ratio: 1.000)
# Copied: 136066.npz (ratio: 1.000)
# Copied: 12077.npz (ratio: 1.000)
# Copied: 11137.npz (ratio: 1.000)
# Copied: 13389.npz (ratio: 1.000)
# Copied: 6579.npz (ratio: 1.000)
# Copied: 170380.npz (ratio: 1.000)
# Copied: 27057.npz (ratio: 1.000)
# Copied: 69464.npz (ratio: 1.000)
# Copied: 37987.npz (ratio: 1.000)
# Copied: 8663.npz (ratio: 1.000)
# Copied: 289.npz (ratio: 1.000)
# Copied: 150790.npz (ratio: 1.000)
# Copied: 61341.npz (ratio: 1.000)
# Copied: 24529.npz (ratio: 1.000)
# Copied: 67508.npz (ratio: 1.000)
# Copied: 123047.npz (ratio: 1.000)
# Copied: 95210.npz (ratio: 1.000)
# Copied: 32758.npz (ratio: 1.000)
# Copied: 15594.npz (ratio: 1.000)
# Copied: 20751.npz (ratio: 1.000)
# Copied: 155609.npz (ratio: 1.000)
# Copied: 38950.npz (ratio: 1.000)
# Copied: 141902.npz (ratio: 1.000)
# Copied: 136583.npz (ratio: 1.000)
# Copied: 173631.npz (ratio: 1.000)
# Copied: 78802.npz (ratio: 1.000)
# Copied: 136084.npz (ratio: 1.000)
# Copied: 65083.npz (ratio: 0.999)
# Copied: 23905.npz (ratio: 1.000)
# Copied: 115020.npz (ratio: 1.000)
# Copied: 243016.npz (ratio: 1.000)
# Copied: 219596.npz (ratio: 0.999)
# Copied: 185796.npz (ratio: 0.999)
# Copied: 230740.npz (ratio: 1.000)
# Copied: 79485.npz (ratio: 1.000)
# Copied: 137016.npz (ratio: 1.000)
# Copied: 243.npz (ratio: 1.000)
# Copied: 149158.npz (ratio: 1.000)
# Copied: 144965.npz (ratio: 1.000)
# Copied: 74031.npz (ratio: 1.000)
# Copied: 69226.npz (ratio: 1.000)
# Copied: 1871.npz (ratio: 1.000)
# Copied: 139505.npz (ratio: 1.000)
# Copied: 94881.npz (ratio: 1.000)
# Copied: 240531.npz (ratio: 0.999)
# Copied: 242576.npz (ratio: 1.000)
# Copied: 75105.npz (ratio: 1.000)
# Copied: 137597.npz (ratio: 1.000)
# Copied: 239361.npz (ratio: 1.000)
# Copied: 11187.npz (ratio: 1.000)
# Copied: 1176.npz (ratio: 1.000)
# Copied: 768.npz (ratio: 1.000)
# Copied: 21857.npz (ratio: 1.000)
# Copied: 75323.npz (ratio: 1.000)
# Copied: 38028.npz (ratio: 1.000)
# Copied: 87446.npz (ratio: 0.999)
# Copied: 25551.npz (ratio: 1.000)
# Copied: 225431.npz (ratio: 1.000)
# Copied: 55669.npz (ratio: 0.999)
# Copied: 169503.npz (ratio: 1.000)
# Copied: 108885.npz (ratio: 1.000)
# Copied: 18057.npz (ratio: 1.000)
# Copied: 120564.npz (ratio: 1.000)
# Copied: 10765.npz (ratio: 1.000)
# Copied: 152959.npz (ratio: 1.000)
# Copied: 8497.npz (ratio: 1.000)
# Copied: 69266.npz (ratio: 1.000)
# Copied: 138112.npz (ratio: 1.000)
# Copied: 76490.npz (ratio: 1.000)
# Copied: 67499.npz (ratio: 1.000)
# Copied: 78145.npz (ratio: 1.000)
# Copied: 9999.npz (ratio: 1.000)
# Copied: 484.npz (ratio: 1.000)
# Copied: 141095.npz (ratio: 1.000)
# Copied: 75734.npz (ratio: 1.000)
# Copied: 62453.npz (ratio: 1.000)
# Copied: 20695.npz (ratio: 1.000)
# Copied: 92529.npz (ratio: 1.000)
# Copied: 139149.npz (ratio: 1.000)
# Copied: 21501.npz (ratio: 1.000)
# Copied: 78077.npz (ratio: 1.000)
# Copied: 61222.npz (ratio: 1.000)
# Copied: 355.npz (ratio: 1.000)
# Copied: 12781.npz (ratio: 1.000)
# Copied: 71073.npz (ratio: 1.000)
# Copied: 69975.npz (ratio: 1.000)
# Copied: 123444.npz (ratio: 1.000)
# Copied: 152043.npz (ratio: 1.000)
# Copied: 96600.npz (ratio: 1.000)
# Copied: 723.npz (ratio: 1.000)
# Copied: 18980.npz (ratio: 1.000)
# Copied: 13396.npz (ratio: 0.999)
# Copied: 135793.npz (ratio: 1.000)
# Copied: 1188.npz (ratio: 1.000)
# Copied: 149137.npz (ratio: 1.000)
# Copied: 12792.npz (ratio: 1.000)
# Copied: 145773.npz (ratio: 1.000)
# Copied: 32362.npz (ratio: 1.000)
# Copied: 222902.npz (ratio: 1.000)
# Copied: 220711.npz (ratio: 1.000)
# Copied: 61009.npz (ratio: 1.000)
# Copied: 156602.npz (ratio: 1.000)
# Copied: 13219.npz (ratio: 1.000)
# Copied: 12828.npz (ratio: 1.000)
# Copied: 96695.npz (ratio: 1.000)
# Copied: 938.npz (ratio: 1.000)
# Copied: 65531.npz (ratio: 1.000)
# Copied: 11901.npz (ratio: 1.000)
# Copied: 7047.npz (ratio: 1.000)
# Copied: 8405.npz (ratio: 1.000)
# Copied: 101030.npz (ratio: 1.000)
# Copied: 10331.npz (ratio: 1.000)
# Copied: 13854.npz (ratio: 1.000)
# Copied: 96580.npz (ratio: 1.000)
# Copied: 81449.npz (ratio: 1.000)
# Copied: 12076.npz (ratio: 1.000)
# Copied: 1043.npz (ratio: 1.000)
# Copied: 11375.npz (ratio: 0.999)
# Copied: 8024.npz (ratio: 1.000)
# Copied: 12577.npz (ratio: 1.000)
# Copied: 249778.npz (ratio: 1.000)
# Copied: 79510.npz (ratio: 0.999)
# Copied: 281.npz (ratio: 1.000)
# Copied: 61208.npz (ratio: 1.000)
# Copied: 795.npz (ratio: 1.000)
# Copied: 139183.npz (ratio: 1.000)
# Copied: 227928.npz (ratio: 1.000)
# Copied: 243453.npz (ratio: 1.000)
# Copied: 7006.npz (ratio: 1.000)
# Copied: 80006.npz (ratio: 1.000)
# Copied 897 molecules meeting the planarity threshold.
